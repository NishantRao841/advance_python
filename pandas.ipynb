# %%
# Pandas -> Pandas is a library which is used to manipulate the data,and analys the data
# pandas is built on the top of Numpy library
# to read the csv file we use the read_csv method
# read_csv('path_of _file')
# pandas have two different data type
# 1. series
# 2. Data frames

# a series is a primary pandas data structure that is built on top of numpy arrays
# while numpy excel at fast numerical operation on

# %%
# create a series wiyh the help of numpy array
import numpy as np
pd.Series(np.array([1,2,3,4]))

# %%
# created series with the help of numpy array
pd.Series(np.array([1,2,3,4]),index=['a','b','c','d'])

# %%
# creating a series with the help of list
li=[1,2,3,4]
li_idx=['a','b','c','d']
pd.Series(li,index=li_idx)

# %%
# creating a series with the help of dictionary
d={
    'a':10,
    'b':20,
    'c':30,
    'd':40,
}
s1=pd.Series(d)

# When we create any series with the help of dictionary
# key->index, value-> value

# %%
# .values is used to retrive the values of the series
# it returns the values into the form of the numpy array
s1.values

# %%
# .index method is used to find all the indices of the series
s1.index

# %%
s1.dtype

# %%
# Vectorised operations
s1=pd.Series([1,2,3,4])
s2=pd.Series([5,6,7,8])
s1+s2

# %%
# accessing the elements usung indices
series=pd.Series(np.arange(1,13))
# we can access the elements of the series using some conditions
series[series>5]

# %%
series[series%2==0]

# %%
# data frames-> A pandas dataframe is a primary ,two-dimensional,table-like data structure for data manipulation and analysis on python
# key component
# A DataFrame is composrd of three main parts
# ->Data: the actual values contained within the table
# Rows

# %%
student_details=[
    ['Rahul','Maths',50,'Jaipur'],
    ['Aman','Science',60,'Delhi'],
    ['Naman','English',70,'Mumbai']
]
pd.DataFrame(student_details, columns=['Name','Sub','Marks','Address'])

# %%
import pandas as pd
import numpy as np

# %%
student_details=[
    ['Rahul','Maths',50,'Jaipur'],
    ['Aman','Science',60,'Delhi'],
    ['Naman','English',70,'Mumbai']
]
df=pd.DataFrame(student_details, columns=['Name','Sub','Marks','Address'])
df
# Out:
#     Name      Sub  Marks Address
# 0  Rahul    Maths     50  Jaipur
# 1   Aman  Science     60   Delhi
# 2  Naman  English     70  Mumbai

# %%
# converting  a dataframe to csv format
df.to_csv('student_data.csv')
df.to_excel('srudent_data.xlsx')

# %%
# Pandas-> Read,csv,read_csv('path')
# write -> to_csv -> apply on the data frame
# to_csv('filename.csv')

# %%
df=pd.read_csv('/content/sample_data/california_housing_train.csv')

# %%
df.columns
# df.columns -> gives the columns names which are present into the data
# frame
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
# Selecting the only one column from the dataframe.
# df_name['column_name]
df['total_bedrooms']
# Out:
# 0        1283.0
# 1        1901.0
# 2         174.0
# 3         337.0
# 4         326.0
#           ...
# 16995     394.0
# 16996     528.0
# 16997     531.0
# 16998     552.0
# 16999     300.0
# Name: total_bedrooms, Length: 17000, dtype: float64

# %%
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
# selecting the multiple columns using the list of the columns which you want to show
df[['total_bedrooms','longitude','latitude','population']]
# Out:
#        total_bedrooms  longitude  latitude  population
# 0              1283.0    -114.31     34.19      1015.0
# 1              1901.0    -114.47     34.40      1129.0
# 2               174.0    -114.56     33.69       333.0
# 3               337.0    -114.57     33.64       515.0
# 4               326.0    -114.57     33.57       624.0
# ...               ...        ...       ...         ...
# 16995           394.0    -124.26     40.58       907.0
# 16996           528.0    -124.27     40.69      1194.0
# 16997           531.0    -124.30     41.84      1244.0
# 16998           552.0    -124.30     41.80      1298.0
# 16999           300.0    -124.35     40.54       806.0
#
# [17000 rows x 4 columns]

# %%
# To select the first row of the dataframe
df.loc[0]
# Out:
# longitude              -114.3100
# latitude                 34.1900
# housing_median_age       15.0000
# total_rooms            5612.0000
# total_bedrooms         1283.0000
# population             1015.0000
# households              472.0000
# median_income             1.4936
# median_house_value    66900.0000
# Name: 0, dtype: float64

# %%
# into this slicing the end included
# Df.loc is used to retrive the row using the labels
# to select the multiple rows with multiple columns
# df.loc[row_labels, columns_labels]
df.loc[0:6]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0
# ...

# %%
student_details={
    'Name':['Rahul','Aman','Naman'],
    'Sub':['Maths','Science','English'],
    'Marks':[50,60,70],
    'Address':['Jaipur','Delhi','Mumbai']
}
df1=pd.DataFrame(student_details,index=['a','b','c'])
df1
# Out:
#     Name      Sub  Marks Address
# a  Rahul    Maths     50  Jaipur
# b   Aman  Science     60   Delhi
# c  Naman  English     70  Mumbai

# %%
# select all rows of the daataframe and also select three any columns
df.loc[0:,['longitude','latitude','population']]
# Out:
#        longitude  latitude  population
# 0        -114.31     34.19      1015.0
# 1        -114.47     34.40      1129.0
# 2        -114.56     33.69       333.0
# 3        -114.57     33.64       515.0
# 4        -114.57     33.57       624.0
# ...          ...       ...         ...
# 16995    -124.26     40.58       907.0
# 16996    -124.27     40.69      1194.0
# 16997    -124.30     41.84      1244.0
# 16998    -124.30     41.80      1298.0
# 16999    -124.35     40.54       806.0
#
# [17000 rows x 3 columns]

# %%
# to select the multiple rows with multiple columns

# %%
# df.iloc access the rows and columns  based on integer position of the rows and columns
# into this slicing is name the normal python slicing
# end -> exclusive
# Syntax of the
df.iloc[0:4,0:4]
# Out:
#    longitude  latitude  housing_median_age  total_rooms
# 0    -114.31     34.19                15.0       5612.0
# 1    -114.47     34.40                19.0       7650.0
# 2    -114.56     33.69                17.0        720.0
# 3    -114.57     33.64                14.0       1501.0
