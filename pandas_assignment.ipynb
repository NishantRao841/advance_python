# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/StudentsPerformance.csv')

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.size
# Out:
# 8000

# %%
df.ndim
# Out:
# 2

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df[['math score','reading score']]
# Out:
#      math score  reading score
# 0            72             72
# 1            69             90
# 2            90             95
# 3            47             57
# 4            76             78
# ..          ...            ...
# 995          88             99
# 996          62             55
# 997          59             71
# 998          68             78
# 999          77             86
#
# [1000 rows x 2 columns]

# %%
df['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
df['lunch'].nunique()
# Out:
# 2

# %%
df[df['math score'] > 80]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 2    female        group B             master's degree      standard
# 6    female        group B                some college      standard
# 16     male        group C                 high school      standard
# 34     male        group E                some college      standard
# 35     male        group E          associate's degree      standard
# ..      ...            ...                         ...           ...
# 979  female        group C          associate's degree      standard
# 981    male        group D            some high school      standard
# 987    male        group E            some high school      standard
# 990    male        group E                 high school  free/reduced
# 995  female        group E             master's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df['math score'] > 80
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 995     True
# 996    False
# 997    False
# 998    False
# 999    False
# Name: math score, Length: 1000, dtype: bool

# %%
df[df['writing score'] < 50]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 7      male        group B                some college  free/reduced
# 11     male        group D          associate's degree      standard
# 17   female        group B            some high school  free/reduced
# 18     male        group C             master's degree  free/reduced
# ..      ...            ...                         ...           ...
# 921  female        group C                 high school  free/reduced
# 928    male        group E          associate's degree  free/reduced
# 978    male        group D                 high school      standard
# 980  female        group B                 high school  free/reduced
# 988  female        group A            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df[df['test preparation course'] == 'completed']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df[df['lunch']=='free/reduced']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0      True        group B           bachelor's degree  free/reduced
# 1      True        group C                some college  free/reduced
# 2      True        group B             master's degree  free/reduced
# 3     False        group A          associate's degree  free/reduced
# 4      True        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    True        group E             master's degree  free/reduced
# 996   False        group C                 high school  free/reduced
# 997   False        group C                 high school  free/reduced
# 998    True        group D                some college  free/reduced
# 999    True        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
avg=df['math score'].mean()
avg
# Out:
# np.float64(66.089)

# %%
df['reading score'].max()
# Out:
# 100

# %%
df['reading score'].min()
# Out:
# 17

# %%
df.groupby('race/ethnicity').size()
# Out:
# race/ethnicity
# group A     89
# group B    190
# group C    319
# group D    262
# group E    140
# dtype: int64

# %%
df.groupby('gender')['writing score'].mean()
# Out:
# gender
# False    56.998162
# True     81.243421
# Name: writing score, dtype: float64

# %%
df['math score'].sort_values(ascending=False).head(10)
# Out:
# 451    100
# 458    100
# 962    100
# 149    100
# 623    100
# 625    100
# 916    100
# 114     99
# 263     99
# 306     99
# Name: math score, dtype: int64

# %%
total=df['total_score']= df['math score'] + df['reading score'] + df['writing score']
total
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Length: 1000, dtype: int64

# %%
average=df['average_score']=df['total_score']/3
average
# Out:
# 0      72.666667
# 1      82.333333
# 2      92.666667
# 3      49.333333
# 4      76.333333
#          ...
# 995    94.000000
# 996    57.333333
# 997    65.000000
# 998    74.333333
# 999    83.000000
# Name: total_score, Length: 1000, dtype: float64

# %%
df['result']=np.where(df['average_score']>=60,'pass','fail')

# %%
df.sort_values(by='total_score',ascending=True).head(5)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59    False        group C            some high school  free/reduced
# 980   False        group B                 high school  free/reduced
# 596   False        group B                 high school  free/reduced
# 327   False        group A                some college  free/reduced
# 17    False        group B            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 59                completed           0             17             10
# 980               completed           8             24             23
# 596               completed          30             24             15
# 327               completed          28             23             19
# 17                completed          18             32             28
#
#      total_score  average_score result
# 59            27       9.000000   fail
# 980           55      18.333333   fail
# ...

# %%
df.sort_values(by='math score',ascending=True).tail(5)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 623    True        group A                some college  free/reduced
# 625    True        group D                some college  free/reduced
# 962    True        group E          associate's degree  free/reduced
# 458    True        group E           bachelor's degree  free/reduced
# 916    True        group E           bachelor's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 623               completed         100             96             86
# 625               completed         100             97             99
# 962               completed         100            100            100
# 458               completed         100            100            100
# 916               completed         100            100            100
#
#      total_score  average_score result
# 623          282      94.000000   pass
# 625          296      98.666667   pass
# ...
