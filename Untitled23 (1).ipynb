# %%
import pandas as pd

# %%
df = pd.read_csv("/content/covid_toy - covid_toy.csv")

# %%
df.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
# Descrete(Categorical)---> we cannot divide further. Ex. Result(pass,fail), Marital status,Number of employees
# Continuous(Numerical)---> We can divide further. Ex. distance(km),birth,salary

# %%
# if data is descrete --->most_frquent
# if data is continuous --->mean

# %%
df['fever']= df['fever'].fillna(df['fever'].mean())

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
df['has_covid'].value_counts()
# Out:
# has_covid
# No     55
# Yes    45
# Name: count, dtype: int64

# %%
df['gender']=df['gender'].map({'Female':0, 'Male':1})

# %%
df['cough']=df['cough'].map({'Mild':0, 'Strong':1})

# %%
df['city']=df['city'].map({'Kolakata':0, 'Banglore':2, 'Delhi':1, 'Mumbai':3})

# %%
df['has_covid']=df['has_covid'].map({'No':0,'Yes':1})

# %%
df.sample(5)
# Out:
#     age  gender       fever  cough  city  has_covid
# 43   22       0   99.000000      0   NaN          1
# 46   19       0  101.000000      0   3.0          0
# 57   49       0   99.000000      1   NaN          0
# 56   71       1  100.844444      1   NaN          0
# 17   40       0   98.000000      1   1.0          0

# %%
df.dtypes
# Out:
# age            int64
# gender         int64
# fever        float64
# cough          int64
# city         float64
# has_covid      int64
# dtype: object

# %%
df_new=pd.read_csv('/content/covid_toy - covid_toy.csv')

# %%
df_new=df_new.dropna()

# %%
#df.describe()

# %%
# x=1,2,3,4
# mean=(1+2+3+4)/4=10/4=2.5

# %%
# centroid--->mean,median,mode

# %%
# df.head(3)

# %%
df['fever']= df['fever'].astype(int)

# %%
# df.head(2)

# %%
a=df_new[['gender','fever']][3:7]=50
# Out:
# /tmp/ipython-input-1170678834.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a=df_new[['gender','fever']][3:7]=50

# %%
df.head(3)
# Out:
#    age  gender  updated_fever  cough  city  has_covid
# 0   60       1            103      0   NaN          0
# 1   27       1            100      0   1.0          1
# 2   42       1            101      0   1.0          0

# %%
df=df.rename(columns={'fever':'updated_fever'})

# %%
df.head(2)
# Out:
#    age  gender  updated_fever  cough  city  has_covid
# 0   60       1            103      0   NaN          0
# 1   27       1            100      0   1.0          1

# %%
# EDA---> Exploratory data analysis

# %%
# parts of EDA
# 1. Univariate Analysis ==> analysis of single variable
# 2. Bivariate Analysis ==> analysis of two variables
# 3. Multivariate Analysis ==> analysis of more than two column

# %%
# data types
# 1.numerical data==> continous data==> age(year,month,days), height weight etc
# 2. Categorical data==> Descrete data==> Toral number of employees, marital status, student result

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt  # Visualization library
import seaborn as sns   # matplotib

# %%
df=pd.read_csv('/content/titanic - titanic.csv')

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# if we want to see actual values than we use value_counts()
df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Survived'].value_counts().plot(kind='pie' , autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
#  If we have Numerical data then we use Histogram
#  because it finds the distribution

# %%
plt.hist(x=df['Age'])
plt.show()

# %%
# from dataclasses import dataclass
# from os import fsencode
# Boxplot
# for find  our outliers

# 1. Lower fence
# 2. 25% data
# 3.IQR( Inter Quartile Range)(75%-25%)
# 4.75% data
# 5.upper fence

# %%
x=1,2,3,4,5
mean=(1)

# %%
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
df['Pclass']

# %%
df['Sex']=df['Sex'].map({'Female':0, 'Male':1})

# %%
df['Pclass'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
plt.show()
